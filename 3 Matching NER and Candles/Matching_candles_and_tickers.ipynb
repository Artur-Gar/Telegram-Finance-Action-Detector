# %%
import pandas as pd
from datetime import timedelta
import numpy as np

# %%
# paths and files
path_df_tickers = ".../2 NER/data/parsed_and_extracted_tickers.xlsx"
path_df_candles = "data/sechist_to_Arthur.xlsx"

df_tickers = pd.read_excel(path_df_tickers).iloc[:,1:] # Messages from Telegram chats where specific tickers are mentioned and identified
df_candles = pd.read_excel(path_df_candles).iloc[:,1:] # time series data of ticker candles

# %%
# We include only tickers that were mentioned on Telegram and are listed at level 2 or above
considered_tickers = df_tickers['security_id'].unique()
filter_1 = df_candles['securityid'].apply(lambda x: x in considered_tickers)
filter_2 = df_candles['listlevel'].apply(lambda x: x > 1)
df_candles = df_candles[filter_1 & filter_2]

# %%
# For each ticker, we normalize the current high and low prices by dividing them by yesterday’s closing price.
df_candles['deviation_high'] = df_candles['highprice'] / df_candles.groupby('securityid')['closeprice'].transform(lambda x: x.shift(1))
df_candles['deviation_low'] = df_candles['lowprice'] / df_candles.groupby('securityid')['closeprice'].transform(lambda x: x.shift(1))

# %%
# We remove missing values and compute the quantile.
df_candles = df_candles.dropna()

df_candles['quantile_high'] = df_candles.groupby(['securityid'])['deviation_high'].transform(lambda x: x.quantile(0.9))
df_candles['quantile_low'] = df_candles.groupby(['securityid'])['deviation_low'].transform(lambda x: x.quantile(0.1))

# %%
# filter anomalies: keep only values which fall below the 10th or exceed the 90th percentile
filter_ = (df_candles['deviation_high'] > df_candles['quantile_high']) | (df_candles['deviation_low'] < df_candles['quantile_low'])

df_filtered = df_candles[filter_].reset_index(drop=True)
df_filtered
# Out:
#      boardid securityid  tradedate  openprice  highprice  lowprice  \
# 0       TQBR       ABIO 2024-01-04    104.100    110.980   103.500
# 1       TQBR       ABIO 2024-01-15    109.880    115.320   109.120
# 2       TQBR       ABIO 2024-01-25    111.820    113.800   106.300
# 3       TQBR       ABIO 2024-02-21    105.000    105.140    99.160
# 4       TQBR       ABIO 2024-03-20    102.160    115.000   102.160
# ...      ...        ...        ...        ...        ...       ...
# 2015    TQBR       KLVZ 2024-07-04      6.878      6.930     6.520
# 2016    TQBR       KLVZ 2024-07-05      6.720      6.740     6.400
# 2017    TQBR       KLVZ 2024-07-11      6.048      6.340     6.000
# 2018    TQBR       KLVZ 2024-07-19      6.130      6.628     6.118
# 2019    TQBR       KLVZ 2024-07-25      6.358      6.664     6.264
#
#       closeprice  listlevel  deviation_high  deviation_low  quantile_high  \
# 0        109.440        2.0        1.074763       1.002324       1.050060
# 1        111.500        2.0        1.057206       1.000367       1.050060
# 2        107.240        2.0        1.017707       0.950635       1.050060
# 3        102.600        2.0        0.994138       0.937595       1.050060
# 4        109.800        2.0        1.125685       1.000000       1.050060
# ...          ...        ...             ...            ...            ...
# 2015       6.726        3.0        1.007560       0.947950       1.045459
# 2016       6.506        3.0        1.002081       0.951531       1.045459
# 2017       6.310        3.0        1.048280       0.992063       1.045459
# 2018       6.300        3.0        1.083715       1.000327       1.045459
# 2019       6.368        3.0        1.047799       0.984906       1.045459
#
#       quantile_low
# 0         0.961169
# 1         0.961169
# 2         0.961169
# 3         0.961169
# 4         0.961169
# ...            ...
# 2015      0.953315
# 2016      0.953315
# 2017      0.953315
# 2018      0.953315
# 2019      0.953315
#
# [2020 rows x 12 columns]

# %%
# keep tickers that were mentioned more than 5 times in the same chat on the same day
df_anomalys = df_tickers.groupby(['chat', 'date', 'security_id'])['security_id'].count().reset_index(name='count').sort_values(by='count', ascending=False)
filter = df_anomalys['count'] > 5

df_anomalys = df_anomalys[filter].reset_index(drop=True)
df_anomalys.head(10)
# Out:
#           chat       date security_id  count
# 0  BigBro_moex 2024-07-18        SNGS     65
# 1  BigBro_moex 2024-06-20        TATN     22
# 2  BigBro_moex 2024-05-15        SNGS     22
# 3  BigBro_moex 2024-05-31        MGNT     20
# 4  BigBro_moex 2024-06-13        MOEX     16
# 5  BigBro_moex 2024-07-17        SNGS     15
# 6  BigBro_moex 2024-05-21        MGNT     12
# 7  BigBro_moex 2024-06-03        MGNT     11
# 8  BigBro_moex 2024-07-09        SBER     10
# 9  BigBro_moex 2024-05-13        SNGS     10

# %%
### We attempt to measure the impact of messages on the following day!
df_anomalys = df_anomalys.rename({'security_id': 'securityid', 'date': 'date_of_discussion'}, axis='columns')
df_anomalys['tradedate'] = df_anomalys['date_of_discussion'].apply(lambda x: x + timedelta(days=1))

merged_data= df_anomalys.merge(df_filtered, on=["tradedate","securityid"])
merged_data
# Out:
#                         chat date_of_discussion securityid  count  tradedate  \
# 0   birzhevikstocksofficial2         2024-06-17       UNAC      4 2024-06-18
# 1                BigBro_moex         2024-06-19       SNGS      3 2024-06-20
# 2                BigBro_moex         2024-07-15       MGNT      3 2024-07-16
# 3                BigBro_moex         2024-07-25       SIBN      3 2024-07-26
# 4   birzhevikstocksofficial2         2024-05-16       ROSB      3 2024-05-17
# 5               smartlabnews         2024-05-16       ROSB      2 2024-05-17
# 6                    kuzmlab         2024-05-13       SPBE      2 2024-05-14
# 7                    araketa         2024-07-23       NKHP      2 2024-07-24
# 8                BigBro_moex         2024-06-04       SIBN      2 2024-06-05
# 9   birzhevikstocksofficial2         2024-06-18       RUSI      2 2024-06-19
# 10               BigBro_moex         2024-06-06       SIBN      2 2024-06-07
# 11               BigBro_moex         2024-05-30       MGNT      2 2024-05-31
# 12               BigBro_moex         2024-05-28       SIBN      2 2024-05-29
# 13          mozgovikresearch         2024-07-09       NKHP      2 2024-07-10
# 14                  moexwolf         2024-07-08       ABIO      2 2024-07-09
#
#    boardid  openprice  highprice   lowprice  closeprice  listlevel  \
# 0     TQBR     0.9985     1.0015     0.9315      0.9505        3.0
# 1     TQBR    27.0000    28.3850    26.8600     28.3300        2.0
# 2     TQBR  5895.0000  5942.5000  5616.0000   5912.0000        3.0
# 3     TQBR   705.3000   709.2000   684.0000    684.4000        3.0
# 4     TQBR   122.2000   123.8000   116.4000    120.2000        3.0
# 5     TQBR   122.2000   123.8000   116.4000    120.2000        3.0
# 6     TQBR   108.2000   113.8000   108.0000    112.7000        3.0
# 7     TQBR   890.0000   949.0000   852.5000    853.0000        3.0
# 8     TQBR   675.0000   699.8500   670.0000    690.9000        3.0
# 9     TQBR   104.7000   104.8000    99.0000     99.3000        3.0
# 10    TQBR   706.5000   732.9000   703.1000    725.7000        3.0
# 11    TQBR  7746.0000  7746.0000  7072.0000   7072.0000        3.0
# 12    TQBR   718.2000   720.6500   697.0000    707.1000        3.0
# 13    TQBR   797.5000   797.5000   727.0000    737.0000        3.0
# 14    TQBR    90.8400    91.0400    80.0400     82.3600        2.0
#
#     deviation_high  deviation_low  quantile_high  quantile_low
# 0         1.003005       0.932899       1.054073      0.944349
# 1         1.049741       0.993343       1.031627      0.966223
# 2         1.008913       0.953480       1.023422      0.973725
# 3         1.005458       0.969731       1.023951      0.971971
# 4         1.009788       0.949429       1.042891      0.962577
# 5         1.009788       0.949429       1.042891      0.962577
# 6         1.074599       1.019830       1.066140      0.945617
# 7         1.069899       0.961105       1.064705      0.955743
# 8         1.038122       0.993844       1.023951      0.971971
# 9         1.000955       0.945559       1.060904      0.952923
# 10        1.039574       0.997305       1.023951      0.971971
# 11        1.006955       0.919337       1.023422      0.973725
# 12        1.003411       0.970482       1.023951      0.971971
# 13        1.007581       0.918509       1.064705      0.955743
# 14        1.005300       0.883834       1.050060      0.961169

# %%
# Mark deviations where anomalies occurred
merged_data.style.apply(lambda x: ["background: lightgreen" 
                                   if ((i == 11) and (x.iloc[11] > x.iloc[13])) or ((i == 12) and (x.iloc[12] < x.iloc[14]))
                                   else "" for i,_ in enumerate(x)],
                        axis=1
                        )
# Out:
# <style type="text/css">
# #T_8285f_row0_col12, #T_8285f_row1_col11, #T_8285f_row2_col12, #T_8285f_row3_col12, #T_8285f_row4_col12, #T_8285f_row5_col12, #T_8285f_row6_col11, #T_8285f_row7_col11, #T_8285f_row8_col11, #T_8285f_row9_col12, #T_8285f_row10_col11, #T_8285f_row11_col12, #T_8285f_row12_col12, #T_8285f_row13_col12, #T_8285f_row14_col12 {
#   background: lightgreen;
# }
# </style>
# <table id="T_8285f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8285f_level0_col0" class="col_heading level0 col0" >chat</th>
#       <th id="T_8285f_level0_col1" class="col_heading level0 col1" >date_of_discussion</th>
#       <th id="T_8285f_level0_col2" class="col_heading level0 col2" >securityid</th>
#       <th id="T_8285f_level0_col3" class="col_heading level0 col3" >count</th>
#       <th id="T_8285f_level0_col4" class="col_heading level0 col4" >tradedate</th>
#       <th id="T_8285f_level0_col5" class="col_heading level0 col5" >boardid</th>
#       <th id="T_8285f_level0_col6" class="col_heading level0 col6" >openprice</th>
#       <th id="T_8285f_level0_col7" class="col_heading level0 col7" >highprice</th>
#       <th id="T_8285f_level0_col8" class="col_heading level0 col8" >lowprice</th>
#       <th id="T_8285f_level0_col9" class="col_heading level0 col9" >closeprice</th>
#       <th id="T_8285f_level0_col10" class="col_heading level0 col10" >listlevel</th>
#       <th id="T_8285f_level0_col11" class="col_heading level0 col11" >deviation_high</th>
#       <th id="T_8285f_level0_col12" class="col_heading level0 col12" >deviation_low</th>
#       <th id="T_8285f_level0_col13" class="col_heading level0 col13" >quantile_high</th>
#       <th id="T_8285f_level0_col14" class="col_heading level0 col14" >quantile_low</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8285f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8285f_row0_col0" class="data row0 col0" >birzhevikstocksofficial2</td>
#       <td id="T_8285f_row0_col1" class="data row0 col1" >2024-06-17 00:00:00</td>
#       <td id="T_8285f_row0_col2" class="data row0 col2" >UNAC</td>
#       <td id="T_8285f_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_8285f_row0_col4" class="data row0 col4" >2024-06-18 00:00:00</td>
#       <td id="T_8285f_row0_col5" class="data row0 col5" >TQBR</td>
#       <td id="T_8285f_row0_col6" class="data row0 col6" >0.998500</td>
#       <td id="T_8285f_row0_col7" class="data row0 col7" >1.001500</td>
#       <td id="T_8285f_row0_col8" class="data row0 col8" >0.931500</td>
#       <td id="T_8285f_row0_col9" class="data row0 col9" >0.950500</td>
#       <td id="T_8285f_row0_col10" class="data row0 col10" >3.000000</td>
#       <td id="T_8285f_row0_col11" class="data row0 col11" >1.003005</td>
#       <td id="T_8285f_row0_col12" class="data row0 col12" >0.932899</td>
#       <td id="T_8285f_row0_col13" class="data row0 col13" >1.054073</td>
#       <td id="T_8285f_row0_col14" class="data row0 col14" >0.944349</td>
#     </tr>
#     <tr>
#       <th id="T_8285f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8285f_row1_col0" class="data row1 col0" >BigBro_moex</td>
#       <td id="T_8285f_row1_col1" class="data row1 col1" >2024-06-19 00:00:00</td>
#       <td id="T_8285f_row1_col2" class="data row1 col2" >SNGS</td>
#       <td id="T_8285f_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_8285f_row1_col4" class="data row1 col4" >2024-06-20 00:00:00</td>
#       <td id="T_8285f_row1_col5" class="data row1 col5" >TQBR</td>
#       <td id="T_8285f_row1_col6" class="data row1 col6" >27.000000</td>
#       <td id="T_8285f_row1_col7" class="data row1 col7" >28.385000</td>
#       <td id="T_8285f_row1_col8" class="data row1 col8" >26.860000</td>
#       <td id="T_8285f_row1_col9" class="data row1 col9" >28.330000</td>
#       <td id="T_8285f_row1_col10" class="data row1 col10" >2.000000</td>
#       <td id="T_8285f_row1_col11" class="data row1 col11" >1.049741</td>
#       <td id="T_8285f_row1_col12" class="data row1 col12" >0.993343</td>
#       <td id="T_8285f_row1_col13" class="data row1 col13" >1.031627</td>
#       <td id="T_8285f_row1_col14" class="data row1 col14" >0.966223</td>
#     </tr>
#     <tr>
#       <th id="T_8285f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8285f_row2_col0" class="data row2 col0" >BigBro_moex</td>
#       <td id="T_8285f_row2_col1" class="data row2 col1" >2024-07-15 00:00:00</td>
#       <td id="T_8285f_row2_col2" class="data row2 col2" >MGNT</td>
#       <td id="T_8285f_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_8285f_row2_col4" class="data row2 col4" >2024-07-16 00:00:00</td>
#       <td id="T_8285f_row2_col5" class="data row2 col5" >TQBR</td>
#       <td id="T_8285f_row2_col6" class="data row2 col6" >5895.000000</td>
#       <td id="T_8285f_row2_col7" class="data row2 col7" >5942.500000</td>
#       <td id="T_8285f_row2_col8" class="data row2 col8" >5616.000000</td>
#       <td id="T_8285f_row2_col9" class="data row2 col9" >5912.000000</td>
#       <td id="T_8285f_row2_col10" class="data row2 col10" >3.000000</td>
#       <td id="T_8285f_row2_col11" class="data row2 col11" >1.008913</td>
#       <td id="T_8285f_row2_col12" class="data row2 col12" >0.953480</td>
#       <td id="T_8285f_row2_col13" class="data row2 col13" >1.023422</td>
#       <td id="T_8285f_row2_col14" class="data row2 col14" >0.973725</td>
#     </tr>
#     <tr>
#       <th id="T_8285f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8285f_row3_col0" class="data row3 col0" >BigBro_moex</td>
#       <td id="T_8285f_row3_col1" class="data row3 col1" >2024-07-25 00:00:00</td>
#       <td id="T_8285f_row3_col2" class="data row3 col2" >SIBN</td>
#       <td id="T_8285f_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_8285f_row3_col4" class="data row3 col4" >2024-07-26 00:00:00</td>
#       <td id="T_8285f_row3_col5" class="data row3 col5" >TQBR</td>
#       <td id="T_8285f_row3_col6" class="data row3 col6" >705.300000</td>
#       <td id="T_8285f_row3_col7" class="data row3 col7" >709.200000</td>
#       <td id="T_8285f_row3_col8" class="data row3 col8" >684.000000</td>
#       <td id="T_8285f_row3_col9" class="data row3 col9" >684.400000</td>
#       <td id="T_8285f_row3_col10" class="data row3 col10" >3.000000</td>
#       <td id="T_8285f_row3_col11" class="data row3 col11" >1.005458</td>
#       <td id="T_8285f_row3_col12" class="data row3 col12" >0.969731</td>
#       <td id="T_8285f_row3_col13" class="data row3 col13" >1.023951</td>
#       <td id="T_8285f_row3_col14" class="data row3 col14" >0.971971</td>
#     </tr>
#     <tr>
#       <th id="T_8285f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8285f_row4_col0" class="data row4 col0" >birzhevikstocksofficial2</td>
#       <td id="T_8285f_row4_col1" class="data row4 col1" >2024-05-16 00:00:00</td>
#       <td id="T_8285f_row4_col2" class="data row4 col2" >ROSB</td>
#       <td id="T_8285f_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_8285f_row4_col4" class="data row4 col4" >2024-05-17 00:00:00</td>
#       <td id="T_8285f_row4_col5" class="data row4 col5" >TQBR</td>
#       <td id="T_8285f_row4_col6" class="data row4 col6" >122.200000</td>
#       <td id="T_8285f_row4_col7" class="data row4 col7" >123.800000</td>
#       <td id="T_8285f_row4_col8" class="data row4 col8" >116.400000</td>
#       <td id="T_8285f_row4_col9" class="data row4 col9" >120.200000</td>
#       <td id="T_8285f_row4_col10" class="data row4 col10" >3.000000</td>
#       <td id="T_8285f_row4_col11" class="data row4 col11" >1.009788</td>
#       <td id="T_8285f_row4_col12" class="data row4 col12" >0.949429</td>
#       <td id="T_8285f_row4_col13" class="data row4 col13" >1.042891</td>
#       <td id="T_8285f_row4_col14" class="data row4 col14" >0.962577</td>
#     </tr>
#     <tr>
#       <th id="T_8285f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8285f_row5_col0" class="data row5 col0" >smartlabnews</td>
#       <td id="T_8285f_row5_col1" class="data row5 col1" >2024-05-16 00:00:00</td>
#       <td id="T_8285f_row5_col2" class=

# %%
# Find texts relating to those securities which had anomalies 

merged_data = merged_data.loc[:, ['date_of_discussion', 'securityid']]

filter_final = np.full(df_tickers.shape[0], False)
for i in range(merged_data.shape[0]):
    filter_ = (df_tickers['security_id'] == merged_data['securityid'][i]) & (df_tickers['date'] == merged_data['date_of_discussion'][i])
    print(filter_.value_counts())
    filter_final = filter_final | filter_
# Out:
# False    4371
# True        4
# Name: count, dtype: int64
# False    4372
# True        3
# Name: count, dtype: int64
# False    4370
# True        5
# Name: count, dtype: int64
# False    4371
# True        4
# Name: count, dtype: int64
# False    4370
# True        5
# Name: count, dtype: int64
# False    4370
# True        5
# Name: count, dtype: int64
# False    4372
# True        3
# Name: count, dtype: int64
# False    4372
# True        3
# Name: count, dtype: int64
# False    4373
# True        2
# Name: count, dtype: int64
# False    4373
# True        2
# Name: count, dtype: int64
# False    4373
# True        2
# Name: count, dtype: int64
# False    4371
# True        4
# Name: count, dtype: int64
# False    4372
# True        3
# Name: count, dtype: int64
# False    4373
# True        2
# Name: count, dtype: int64
# False    4373
# True        2
# Name: count, dtype: int64

# %%
# Save them
# df_tickers[filter_final].to_excel('data/messages_day_before_anomalys.xlsx')
df_tickers[filter_final].reset_index(drop=True)
# Out:
#                         chat       date      time  \
# 0                   moexwolf 2024-05-13  14:05:26
# 1                    kuzmlab 2024-05-13  14:07:13
# 2                    kuzmlab 2024-05-13  12:29:12
# 3   birzhevikstocksofficial2 2024-05-16  14:23:57
# 4   birzhevikstocksofficial2 2024-05-16  14:23:57
# 5   birzhevikstocksofficial2 2024-05-16  14:23:57
# 6               smartlabnews 2024-05-16  18:53:29
# 7               smartlabnews 2024-05-16  18:53:29
# 8                BigBro_moex 2024-05-28  13:22:27
# 9                BigBro_moex 2024-05-28  12:45:59
# 10                  razb0rka 2024-05-28  18:06:47
# 11               BigBro_moex 2024-05-30  12:00:37
# 12               BigBro_moex 2024-05-30  11:43:39
# 13          mozgovikresearch 2024-05-30  17:26:51
# 14                  razb0rka 2024-05-30  14:09:24
# 15               BigBro_moex 2024-06-04  18:47:55
# 16               BigBro_moex 2024-06-04  15:40:52
# 17               BigBro_moex 2024-06-06  11:00:08
# 18               BigBro_moex 2024-06-06  10:41:56
# 19  birzhevikstocksofficial2 2024-06-17  08:54:08
# 20  birzhevikstocksofficial2 2024-06-17  08:54:08
# 21  birzhevikstocksofficial2 2024-06-17  08:54:08
# 22  birzhevikstocksofficial2 2024-06-17  08:54:08
# 23  birzhevikstocksofficial2 2024-06-18  07:52:11
# 24  birzhevikstocksofficial2 2024-06-18  07:42:01
# 25               BigBro_moex 2024-06-19  17:49:54
# 26               BigBro_moex 2024-06-19  12:49:59
# 27               BigBro_moex 2024-06-19  12:49:58
# 28                  moexwolf 2024-07-08  14:58:32
# 29                  moexwolf 2024-07-08  14:58:32
# 30          mozgovikresearch 2024-07-09  14:11:03
# 31          mozgovikresearch 2024-07-09  14:11:03
# 32               BigBro_moex 2024-07-15  10:04:21
# 33               BigBro_moex 2024-07-15  10:02:39
# 34               BigBro_moex 2024-07-15  10:01:48
# 35            stockoffinvest 2024-07-15  16:26:47
# 36            malishok_fonda 2024-07-15  19:39:32
# 37                   araketa 2024-07-23  12:02:49
# 38                   araketa 2024-07-23  12:02:49
# 39          vadya93_official 2024-07-23  20:08:08
# 40               BigBro_moex 2024-07-25  19:09:57
# 41               BigBro_moex 2024-07-25  18:47:30
# 42               BigBro_moex 2024-07-25  10:00:35
# 43  birzhevikstocksofficial2 2024-07-25  10:11:01
#
#                                                  text               text_id  \
# 0   Соболезную многим Евроклировским \n\nАкции Yan...  -1001511455705_12979
# 1   Спб биржа поэтому растет на 3%? Типа хоть что-...   -1001241408755_7613
# 2   Ясно, а то думал торгануть эппл, теслу и Гонко...   -1001241408755_7610
# 3   💬 Мнение: до чего ж непристойно отрастёт прибы...  -1001313313883_21582
# 4   💬 Мнение: до чего ж непристойно отрастёт прибы...  -1001313313883_21582
# 5   💬 Мнение: до чего ж непристойно отрастёт прибы...  -1001313313883_21582
# 6   Отчётности управляют котировками🔥Акции и инвес...  -1001063908560_12379
# 7   Отчётности управляют котировками🔥Акции и инвес...  -1001063908560_12379
# 8   SIBN #SIBN 720,6₽\n"Газпром нефть" начала пром...  -1001666192661_55122
# 9   SIBN #SIBN 716,1₽\n"ГАЗПРОМ НЕФТЬ" НАЧАЛА ПРОМ...  -1001666192661_55120
# 10  БАШНЕФТЬ дивиденды за 2023 год 🎁\n\nРешение Со...   -1001707166728_2550
# 11  MGNT  #MGNT 7 775,5₽  Магнит ао 🐳\nПАО "Магнит...  -1001666192661_55229
# 12  MGNT    Магнит ао 🐳\n🔴Аномальный объем!\n62М₽ ...  -1001666192661_55226
# 13  Магнит РСБУ 1 кв. 2024 г. - деньги не поднимал...   -1001298248713_1854
# 14  МАГНИТ отчет РСБУ за 1кв'24 🧲\n\nОтчет головно...   -1001707166728_2555
# 15  SIBN #SIBN 655,5₽\nЧлены совета директоров "Га...  -1001666192661_55481
# 16  SIBN #SIBN 671₽\nКандидатами в совет директоро...  -1001666192661_55462
# 17  SIBN #SIBN 698,9₽\n"Газпром нефть" и "Эковей" ...  -1001666192661_55560
# 18  SIBN #SIBN 694,7₽\nОпыт "Газпром нефти" в осво...  -1001666192661_55558
# 19  🇷🇺 Новость: консультанты Сбера и Газпром нефти...  -1001313313883_22076
# 20  🇷🇺 Новость: консультанты Сбера и Газпром нефти...  -1001313313883_22076
# 21  🇷🇺 Новость: консультанты Сбера и Газпром нефти...  -1001313313883_22076
# 22  🇷🇺 Новость: консультанты Сбера и Газпром нефти...  -1001313313883_22076
# 23  🌍 Краткий анализ рынка (18.06.2024): придётся ...  -1001313313883_22096
# 24  🇷🇺 Втб в моменте. Ранее прогноз был тут - http...  -1001313313883_22095
# 25  SNGSP    Сургнфгз-п 🐟\n🔹Аномальный объем!\n156...  -1001666192661_56107
# 26  SNGSP    Сургнфгз-п 🐟\n🟢Аномальный объем!\n154...  -1001666192661_56097
# 27  SNGSP    Сургнфгз-п 🐟\n🟢Аномальный объем!\n154...  -1001666192661_56096
# 28  #ABIO\nМинздрав одобрил проведение клинических...  -1001511455705_13516
# 29  #ABIO\nМинздрав одобрил проведение клинических...  -1001511455705_13516
# 30  Новороссийский комбинат хлебопродуктов (НКХП)....   -1001298248713_1926
# 31  Новороссийский комбинат хлебопродуктов (НКХП)....   -1001298248713_1926
# 32  MGNT    Магнит ао 🐳\n🟢Аномальный объем!\n76М₽ ...  -1001666192661_57177
# 33  MGNT    Магнит ао 🐳\n🟢Аномальный объем!\n63М₽ ...  -1001666192661_57174
# 34  MGNT    Магнит ао 🐳\n🔹Аномальный объем!\n76М₽ ...  -1001666192661_57171
# 35  🍏 $MGNT див гэп, ниже 6000. Время покупать?\n\...   -1001775120617_5484
# 36  🔥Итоги дня: IMOEX -2,1% ( 2.911 п.)\n\n🛢Нефть ...   -1001750974618_2138
# 37                                              #NKHP   -1001754254720_1783
# 38                наши ожидания по #NKHP цели зелёным   -1001754254720_1782
# 39  "Безумие и отвага" — девиз моего подписчика, з...   -1001595771315_1303
# 40  SIBN #SIBN 705,2₽\nЧистая прибыль "Газпром неф...  -1001666192661_57821
# 41  SIBN  #SIBN 705₽  Газпрнефть 🐳\nПАО "Газпром н...  -1001666192661_57820
# 42  SIBN  #SIBN 699,7₽  Газпрнефть 🐳\nПАО "Газпром...  -1001666192661_57772
# 43  🇷🇺 Отчёт: прибыль Газпром Нефти по Мсфо в перв...  -1001313313883_22764
#
#    security_id  matching_score
# 0         SPBE        0.888889
# 1         SPBE        0.888889
# 2         SPBE        1.000000
# 3         ROSB        1.000000
# 4         ROSB        0.933333
# 5         ROSB        1.000000
# 6         ROSB        1.000000
# 7         ROSB        0.933333
# 8         SIBN        1.000000
# 9         SIBN        1.000000
# 10        SIBN        0.960000
# 11        MGNT        1.000000
# 12        MGNT        1.000000
# 13        MGNT        1.000000
# 14        MGNT        1.000000
# 15        SIBN        0.960000
# 16        SIBN        0.960000
# 17        SIBN        1.000000
# 18        SIBN        0.960000
# 19        UNAC        0.923077
# 20        UNAC        1.000000
# 21        UNAC        1.000000
# 22        UNAC        0.813953
# 23        RUSI        0.857143
# 24        RUSI        0.857143
# 25        SNGS        0.888889
# 26        SNGS        0.888889
# 27        SNGS        0.888889
# 28        ABIO        1.000000
# 29        ABIO        1.000000
# 30        NKHP        1.000000
# 31        NKHP        0.915663
# 32        MGNT        1.000000
# 33        MGNT        1.000000
# 34        MGNT        1.000000
# 35        MGNT        1.000000
# 36        MGNT        1.000000
# 37        NKHP        1.000000
# 38        NKHP        1.000000
# 39        NKHP        1.000000
# 40        SIBN        0.960000
# 41        SIBN        1.000000
# 42        SIBN        1.000000
# 43        SIBN        0.960000

# %%
# an example
print(df_tickers[filter_final]['text'].reset_index(drop=True)[12])
# Out:
# MGNT    Магнит ао 🐳
# 🔴Аномальный объем!
# 62М₽ (7 935 лот.)
# 🔸Изм. цены -0,90% ⚡⚡ Цена 7 749,5₽
# Покупки 19% Продажи 81%
#
# Итого за день:
# цена -1,6% ATR 82%
# объем 335М₽, покупки 36%
# кол-во сигн. пок. 0 прод. 1
# 30.05.24  11:42:37  #MGNT
# Отправлено с задержкой.
# Подключай полную версию
# @BigBro_robot
